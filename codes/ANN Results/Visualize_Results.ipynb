# %%
########################################################################################################################
# Filename: Visualize_Results.ipynb
#
# Purpose: Generate visualizations of results generated in 'Generate_ANN_Results.ipynb'
#
# Author(s): Bobby (Robert) Lumpkin
#
# Library Dependencies: numpy, pandas, os, matplotlib
########################################################################################################################

# %% [markdown]
# # Visualizing ANN Training Results

# %%
import numpy as np
import pandas as pd
import os
os.chdir('C:\\Users\\rober\\OneDrive\\Documents\\STAT 6500\\Project\\NewsArticleClassification\\codes\\ANN Results')  ## Set working directory
                                                                                                                      ## to be 'ANN Results'
import matplotlib.pyplot as plt

# %% [markdown]
# ## Learning Rate $ = 0.01$

# %%
## Get the reduced dataset training histories
history_bpmll_FF_lr01_df = pd.read_json('Reduced Data Eval Metrics/BPMLL Feed Forward/history_bpmll_FF_lr01.json')
history_bpmll_RNN_lr01_df = pd.read_json('Reduced Data Eval Metrics/BPMLL RNN/history_bpmll_RNN_lr01.json')
history_ce_FF_lr01_df = pd.read_json('Reduced Data Eval Metrics/Cross Entropy Feed Forward/history_ce_FF_lr01.json')
history_ce_RNN_lr01_df = pd.read_json('Reduced Data Eval Metrics/Cross Entropy RNN/history_ce_RNN_lr01.json')

# %%
## Visualize the 'val_hamming_loss' histories for each model in a single plot
plt.plot(history_bpmll_FF_lr01_df['val_hamming_loss'], label = 'BPMLL FF')
plt.plot(history_bpmll_RNN_lr01_df['val_hamming_loss'], label = 'BPMLL RNN')
plt.plot(history_ce_FF_lr01_df['val_hamming_loss'], label = 'CE FF')
plt.plot(history_ce_RNN_lr01_df['val_hamming_loss'], label = 'CE RNN')
plt.xlabel('Epoch', fontsize = 12)
plt.ylabel('Validation Hamming Loss', fontsize = 12)
plt.legend()
plt.title('Reduced Dataset (Learning Rate = 0.01)', fontsize = 15)
# Out:
# Text(0.5, 1.0, 'Reduced Dataset (Learning Rate = 0.01)')

# %%
## Get and print the validation hamming loss dataframe using learned threshold functions
val_hamming_loss_withThreshold_lr01_df = pd.read_json('Reduced Data Eval Metrics/val_hamming_loss_withThreshold_lr01.json')
val_hamming_loss_withThreshold_lr01_df
# Out:
#    ce_FF_lr01  bpmll_FF_lr01  ce_RNN_lr01  bpmll_RNN_lr01
# 0    0.152098       0.145979     0.244755        0.219406

# %%
## Get the full dataset training histories
history_ce_FF_lr01_full_df = pd.read_json('Full Data Eval Metrics/Cross Entropy Feed Forward/history_ce_FF_lr01_full.json')
history_ce_RNN_lr01_full_df = pd.read_json('Full Data Eval Metrics/Cross Entropy RNN/history_ce_RNN_lr01_full.json')

# %%
## Visualize the 'val_hamming_loss' histories for each model in a single plot
plt.plot(history_ce_FF_lr01_full_df['val_hamming_loss'], label = 'CE FF')
plt.plot(history_ce_RNN_lr01_full_df['val_hamming_loss'], label = 'CE RNN')
plt.xlabel('Epoch', fontsize = 12)
plt.ylabel('Validation Hamming Loss', fontsize = 12)
plt.legend()
plt.title('Full Dataset (Learning Rate = 0.01)', fontsize = 16)
# Out:
# Text(0.5, 1.0, 'Full Dataset (Learning Rate = 0.01)')

# %%
## Get and print the validation hamming loss dataframe using learned threshold functions
val_hamming_loss_withThreshold_lr01_full_df = pd.read_json('Full Data Eval Metrics/val_hamming_loss_withThreshold_lr01.json')
val_hamming_loss_withThreshold_lr01_full_df
# Out:
#    ce_FF_full_lr01  ce_RNN_full_lr01
# 0         0.302083          0.237981

# %% [markdown]
# ## Learning Rate  $= 0.001$

# %%
## Get the reduced dataset training histories
history_bpmll_FF_lr001_df = pd.read_json('Reduced Data Eval Metrics/BPMLL Feed Forward/history_bpmll_FF_lr001.json')
history_bpmll_RNN_lr001_df = pd.read_json('Reduced Data Eval Metrics/BPMLL RNN/history_bpmll_RNN_lr001.json')
history_ce_FF_lr001_df = pd.read_json('Reduced Data Eval Metrics/Cross Entropy Feed Forward/history_ce_FF_lr001.json')
history_ce_RNN_lr001_df = pd.read_json('Reduced Data Eval Metrics/Cross Entropy RNN/history_ce_RNN_lr001.json')

# %%
## Visualize the 'val_hamming_loss' histories for each model in a single plot
plt.plot(history_bpmll_FF_lr001_df['val_hamming_loss'], label = 'BPMLL FF')
plt.plot(history_bpmll_RNN_lr001_df['val_hamming_loss'], label = 'BPMLL RNN')
plt.plot(history_ce_FF_lr001_df['val_hamming_loss'], label = 'CE FF')
plt.plot(history_ce_RNN_lr001_df['val_hamming_loss'], label = 'CE RNN')
plt.xlabel('Epoch', fontsize = 12)
plt.ylabel('Validation Hamming Loss', fontsize = 12)
plt.legend()
plt.title('Reduced Dataset (Learning Rate = 0.001)', fontsize = 16)
# Out:
# Text(0.5, 1.0, 'Reduced Dataset (Learning Rate = 0.001)')

# %%
## Get and print the validation hamming loss dataframe using learned threshold functions
val_hamming_loss_withThreshold_lr001_df = pd.read_json('Reduced Data Eval Metrics/val_hamming_loss_withThreshold_lr001.json')
val_hamming_loss_withThreshold_lr001_df
# Out:
#    ce_FF_lr001  bpmll_FF_lr001  ce_RNN_lr001  bpmll_RNN_lr001
# 0     0.185315        0.257867      0.179196         0.204545

# %%
## Get the full dataset training histories
history_ce_FF_lr001_full_df = pd.read_json('Full Data Eval Metrics/Cross Entropy Feed Forward/history_ce_FF_lr001_full.json')
history_ce_RNN_lr001_full_df = pd.read_json('Full Data Eval Metrics/Cross Entropy RNN/history_ce_RNN_lr001_full.json')

# %%
## Visualize the 'val_hamming_loss' histories for each model in a single plot
plt.plot(history_ce_FF_lr001_full_df['val_hamming_loss'], label = 'CE FF')
plt.plot(history_ce_RNN_lr001_full_df['val_hamming_loss'], label = 'CE RNN')
plt.xlabel('Epoch', fontsize = 12)
plt.ylabel('Validation Hamming Loss', fontsize = 12)
plt.legend()
plt.title('Full Dataset (Learning Rate = 0.001)', fontsize = 16)
# Out:
# Text(0.5, 1.0, 'Full Dataset (Learning Rate = 0.001)')

# %%
## Get and print the validation hamming loss dataframe using learned threshold functions
val_hamming_loss_withThreshold_lr001_full_df = pd.read_json('Full Data Eval Metrics/val_hamming_loss_withThreshold_lr001.json')
val_hamming_loss_withThreshold_lr001_full_df
# Out:
#    ce_FF_full_lr001  ce_RNN_full_lr001
# 0          0.178686           0.173077

# %% [markdown]
# ## Learning Rate $= 0.0001$

# %%
## Get the reduced dataset training histories
history_bpmll_FF_lr0001_df = pd.read_json('Reduced Data Eval Metrics/BPMLL Feed Forward/history_bpmll_FF_lr0001.json')
history_bpmll_RNN_lr0001_df = pd.read_json('Reduced Data Eval Metrics/BPMLL RNN/history_bpmll_RNN_lr0001.json')
history_ce_FF_lr0001_df = pd.read_json('Reduced Data Eval Metrics/Cross Entropy Feed Forward/history_ce_FF_lr0001.json')
history_ce_RNN_lr0001_df = pd.read_json('Reduced Data Eval Metrics/Cross Entropy RNN/history_ce_RNN_lr0001.json')

# %%
## Visualize the 'val_hamming_loss' histories for each model in a single plot
plt.plot(history_bpmll_FF_lr0001_df['val_hamming_loss'], label = 'BPMLL FF')
plt.plot(history_bpmll_RNN_lr0001_df['val_hamming_loss'], label = 'BPMLL RNN')
plt.plot(history_ce_FF_lr0001_df['val_hamming_loss'], label = 'CE FF')
plt.plot(history_ce_RNN_lr0001_df['val_hamming_loss'], label = 'CE RNN')
plt.xlabel('Epoch', fontsize = 12)
plt.ylabel('Validation Hamming Loss', fontsize = 12)
plt.legend()
plt.title('Reduced Dataset (Learning Rate = 0.0001)', fontsize = 16)
# Out:
# Text(0.5, 1.0, 'Reduced Dataset (Learning Rate = 0.0001)')

# %%
## Get and print the validation hamming loss dataframe using learned threshold functions
val_hamming_loss_withThreshold_lr0001_df = pd.read_json('Reduced Data Eval Metrics/val_hamming_loss_withThreshold_lr0001.json')
val_hamming_loss_withThreshold_lr0001_df
# Out:
#    ce_FF_lr0001  bpmll_FF_lr0001  ce_RNN_lr0001  bpmll_RNN_lr0001
# 0      0.207168         0.184441       0.189685          0.213287

# %%
## Get the full dataset training histories
history_ce_FF_lr0001_full_df = pd.read_json('Full Data Eval Metrics/Cross Entropy Feed Forward/history_ce_FF_lr0001_full.json')
history_ce_RNN_lr0001_full_df = pd.read_json('Full Data Eval Metrics/Cross Entropy RNN/history_ce_RNN_lr0001_full.json')

# %%
## Visualize the 'val_hamming_loss' histories for each model in a single plot
plt.plot(history_ce_FF_lr0001_full_df['val_hamming_loss'], label = 'CE FF')
plt.plot(history_ce_RNN_lr0001_full_df['val_hamming_loss'], label = 'CE RNN')
plt.xlabel('Epoch', fontsize = 12)
plt.ylabel('Validation Hamming Loss', fontsize = 12)
plt.legend()
plt.title('Full Dataset (Learning Rate = 0.0001)', fontsize = 16)
# Out:
# Text(0.5, 1.0, 'Full Dataset (Learning Rate = 0.0001)')

# %%
## Get and print the validation hamming loss dataframe using learned threshold functions
val_hamming_loss_withThreshold_lr0001_full_df = pd.read_json('Full Data Eval Metrics/val_hamming_loss_withThreshold_lr0001.json')
val_hamming_loss_withThreshold_lr0001_full_df
# Out:
#    ce_FF_full_lr0001  ce_RNN_full_lr0001
# 0           0.211538            0.177083
